# %% [markdown]
# <link rel="stylesheet" href="style.css">
#
# <p class="title_header">lin02:  Using the LU decompostion to solve a linear equations system</p>
#
#
#
#
# <p class="student">Student Name should go here!!</p>

# %% [markdown]
# # The problem:
#
# Solve the linear equation system
#
# \begin{align*}
# x + 7y -4z &= -51\\
# 4x-4y+9z &= 62 \\
# 12x -y +3z &= 8
# \end{align*}
#
# by using the LU decompostion with partial pivoting.

# %% [markdown]
# ## Import packages
#
# Import all necessary functions from `numpy.linalg` and from `scipy.linalg` here  You may need to check these sites to find out what functions to import and how to use them:
#
# - https://numpy.org/doc/stable/reference/routines.linalg.html
# - https://docs.scipy.org/doc/scipy/reference/linalg.html#module-scipy.linalg

# %%
# [WRITE YOUR CODE HERE]

# %% [markdown]
# ## Matrix form
#
# The problem can be solved by writing the system as a matrix equation $Ax=b$
#
# Write code to define `A` and `b`

# %%
A = # [WRITE YOUR CODE HERE]
b = # [WRITE YOUR CODE HERE]

# %% [markdown]
# ## Get the LU decompostion of `A`
#
# Use function `scipy.linalg.lu` to achieve it

# %%
L , U = lu(# [WRITE YOUR CODE HERE])
    
print(f'{L=},\n\n{U=}')  # Print L and U

# %% [markdown]
# ## Verifiy that $LU = A$

# %%
# [WRITE YOUR CODE HERE]

# %% [markdown]
# ## Use L and U to solve the system "by pen and paper", that is, step by step.

# %%
y1 = 8
y2 = "WRITE YOUR CODE HERE" * y1
y3 = "WRITE YOUR CODE HERE" 

x3 = y3 / "WRITE YOUR CODE HERE"
x2 = "WRITE YOU CODE HERE"
x1 = "WRITE YOUR CODE HERE" 

print(f'{x1=},  {x2=},  {x3=}')  # Print x1, x2, x3

# %% [markdown]
# ## Solve the equation directly
#
# That is, use `solve` from `numpy.linalg`. Do you get the same result as before?

# %%
x = # [WRITE YOUR CODE HERE]

x1, x2, x3 = # [WRITE YOUR CODE HERE]

# [WRITE YOUR CODE HERE TO PRINT x1, x2, x3]
