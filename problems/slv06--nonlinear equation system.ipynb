# %% [markdown]
# <link rel="stylesheet" href="style.css">
#
# <p class="title_header">slv06:  A nonlinear equation system</p>
#
#
#
# <p class="student">Student Name should go here!!</p>

# %% [markdown]
# # The problem:
#
# Find the values of $x$ and $y$ that satisfy
#
# \begin{align*}
# x &= y + x^2 - 0.5 \\
# y &= x^2 - 5xy
# \end{align*}
#
# Use the initial values $x=y=1.0$ in all of the algorithms below.

# %% [markdown]
# ## Getting ready: import
#
# Import what you need from `CompEcon`.

# %%
# [WRITE YOUR CODE HERE]

# %% [markdown]
# ## Write the required functions
#
# Code the functions $f: \Re^2 \to \Re^2$ and  $g: \Re^2 \to \Re^2$ to express the system above as a *root-finding* problem and as a *fixed-point* problem, respectively.
#
# The argument of the functions is a size-2 vector. Tip: unpack that vector (see code hint below)

# %%
def f(z):
    x, y = z
    f = # [WRITE YOUR CODE HERE]
    df = # [WRITE YOUR CODE HERE]
    return f, df

def g(z):
    x, y = z
    g = # [WRITE YOUR CODE HERE]
    return # [WRITE YOUR CODE HERE]

# %% [markdown]
# ## Solve the system using function iterations.
#
# - Does it converge?
# - To what values?
# - After how many iterations?

# %%
# [WRITE YOUR CODE HERE]

# %% [markdown]
# ## Solve the system using Newton's method.
#
# - Does it converge?
# - To what values?
# - After how many iterations?

# %%
# [WRITE YOUR CODE HERE]

# %% [markdown]
# ## Solve the system using Broyden's method.
#
# - Does it converge?
# - To what values?
# - After how many iterations?

# %%
# [WRITE YOUR CODE HERE]
