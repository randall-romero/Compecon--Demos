# %% [markdown]
# <link rel="stylesheet" href="style.css">
#
# <p class="title_header">lin01:  Solving a linear equation system</p>
#
# Getting to know `numpy`!
#
# <p class="student">Student Name should go here!!</p>

# %% [markdown]
# # The problem:
#
# Solve this system of linear equations
#
# \begin{align*}
# 3x - 0.1y - 0.2z &= 7.85 \\
# 0.1x + 7y - 0.3z &=-19.3 \\
# 0.3x -0.2y + 10z &= 71.4
# \end{align*}

# %% [markdown]
# ## Import packages
#
# Import the `solve` function from `numpy.linalg`

# %%
# [WRITE YOUR CODE HERE]

# %% [markdown]
# ## Matrix form
#
# The problem can be solved by writing the system as a matrix equation $Ax=b$
#
# Write code to define `A` and `b`

# %%
A = # [WRITE YOUR CODE HERE]
b = # [WRITE YOUR CODE HERE]

# %% [markdown]
# ## Solve the equation
#
# ### Option 1
# Use `solve` to (you guessed it) solve the equation.

# %%
xvec = # [WRITE YOUR CODE HERE]

x, y, z = # [WRITE YOUR CODE HERE]

# %% [markdown]
# ### Option 2
#
# In matrix terms, the solution is $x=A^{-1}b$
#
# Compute the inverse of `A` and obtain the solution. Did you get the same result?

# %%
Ainv = # [WRITE YOUR CODE HERE] 

xnew = # [WRITE YOUR CODE HERE]
