# %% [markdown]
# # This is just a test
#
# Modify this markdown cell so that your name appears below
#
# ## [WRITE YOUR NAME HERE]

# %% [markdown]
# ## Problem 1: A very dificult problem
#
# Use Python to find out how much is 2 times 2

# %%
[YOUR ANSWER HERE]

# %% [markdown]
# # IMPORTANT
#
# After you finish this homework, commmit your work to Github (I am assumming you are using Github Codespaces) before closing Codespaces!
