# %% [markdown]
# <link rel="stylesheet" href="style.css">
#
# <p class="title_header">slv01:  Making your own cubit-root calculator</p>
#
# Ever wonder how calculators can compute cubic roots, using only elementary operations?
#
# Here is your chance to make your own!
#
# <p class="student">Student Name should go here!!</p>

# %% [markdown]
# # The problem:
#
# Write a Python function, call it `raizcubica`, that takes any real number $x$ and returns its cubic root:
# $$\text{raizcubica}(x) = \sqrt[3]{x} $$
#
# The function must use Newton's rootfinding method, starting from initial guess 1.0.
#
# **NOTICE:** Your function can only use elementary operations: `+`, `-`, `*` and `/`.

# %% [markdown]
# ## Import packages

# %%
import unittest

# %% [markdown]
# ## Your function

# %%
def raizcubica(x: float) -> float:
    """
    Compute the cube root of x.

    Parameters
    ----------
    x : float
        The number whose cube root will be computed.

    Returns
    -------
    float
        The cube root of x.
    """

    # TODO: implement the function
    pass

# %% [markdown]
# ## Testing
#
# Test your function computing the cubic roots of $1, -27, 125, \text{and } 512$.  Use `assert` to accomplish this.

# %%
class TestRaizCubica(unittest.TestCase):
    def test_1(self):
        self.assertAlmostEqual(raizcubica(1), 1)

    def test_m27(self):
        pass
        #TODO complete the test below
        #self.assertAlmostEqual(raizcubica(-27), [WRITE NUMBER HERE])

    def test_125(self):
        pass
        #TODO complete the test below

    #TODO: add one more test, for 512
    # [WRITE YOUR TEST HERE]    
        

suite = unittest.TestLoader().loadTestsFromTestCase(TestRaizCubica)
unittest.TextTestRunner().run(suite)

# %% [markdown]
# # Learning more
#
# - Why is the test `assertAlmostEqual` instead of `assertEqual`?
# - How does the `assertAlmostEqual` test work?
#
# Check https://www.geeksforgeeks.org/python/python-unittest-assertalmostequal-function/ for details.
