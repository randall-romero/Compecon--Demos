# %% [markdown]
# <link rel="stylesheet" href="style.css">
#
# <p class="title_header">slv02:  Logit and probit regression</p>
#
# Need to estimate a binary output model but do not have an econometric software. Then learn how to do it yourself!
#
# <p class="student">Student Name should go here!!</p>

# %% [markdown]
# test
#
# ## Problem 2
#
#
#
# Consider this econometric model taken from **Wooldridge (2012) Introductory Econometrics: A Modern Approach**.
#
# As an example, let **inlf** (“in the labor force”) be a binary variable indicating labor force participation by a married woman during 1975: $inlf = 1$ if the woman reports working for a wage outside the home at some point during the year, and zero otherwise.
#
# We assume that labor force participation depends on other sources of income, including
# husband’s earnings (**nwifeinc**, measured in thousands of dollars), years of education (**educ**),
# past years of labor market experience (**exper**), **age**, number of children less than six years
# old (**kidslt6**), and number of kids between 6 and 18 years of age (**kidsge6**). Using the data
# in [MROZ.DTA from Mroz (1987)](http://fmwww.bc.edu/ec-p/data/wooldridge/mroz.dta), available at http://fmwww.bc.edu/ec-p/data/wooldridge/mroz.dta, estimate the following models:
#
# * a linear probability model,
# * a logit model,
# * a probit model.
#
# $$\text{inlf} = f(\text{nwifeinc}, \text{educ}, \text{exper},\text{exper}^2,\text{age},\text{kidslt6},\text{kidsge6})$$
#
# In the sample, 428 of the 753 women report being in the labor force at some point during 1975.
#
# Your code must produce a table (hint: use a Pandas dataframe) with the coefficient estimates, similar to this one:
#
# | Variable  | Linear | Logit | Probit |
# |-----------|--------|-------|--------|
# | intercept |        |       |        |
# | nwifeinc  |        |       |        |
# | educ      |        |       |        |
# | exper     |        |       |        |
# | exper^2   |        |       |        |
# | age       |        |       |        |
# | kidslt6   |        |       |        |
# | kidsge6   |        |       |        |

# %% [markdown]
# # The problem:
#
# Consider this econometric model taken from **Wooldridge (2012) Introductory Econometrics: A Modern Approach**.
#
# Let **inlf** (“in the labor force”) be a binary variable indicating labor force participation by a married woman during 1975: $inlf = 1$ if the woman reports working for a wage outside the home at some point during the year, and zero otherwise.
#
# We assume that labor force participation depends on other sources of income, including
# husband’s earnings (**nwifeinc**, measured in thousands of dollars), years of education (**educ**),
# past years of labor market experience (**exper**), **age**, number of children less than six years
# old (**kidslt6**), and number of kids between 6 and 18 years of age (**kidsge6**). Using the data
# in [MROZ.DTA from Mroz (1987)](http://fmwww.bc.edu/ec-p/data/wooldridge/mroz.dta), available at http://fmwww.bc.edu/ec-p/data/wooldridge/mroz.dta, estimate the following models:
#
# * a linear probability model,
# * a logit model,
# * a probit model.
#
# $$\text{inlf} = f(\text{nwifeinc}, \text{educ}, \text{exper},\text{exper}^2,\text{age},\text{kidslt6},\text{kidsge6})$$
#
# In the sample, 428 of the 753 women report being in the labor force at some point during 1975.
#
# Your code must produce a Pandas table, where the index contains the variable names, and the three columns are "Linear", "Logit" and "Probit. Cell values are the coefficient estimates.

# %% [markdown]
# ## Import packages

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ## Getting the data
#
# Get the data into a pandas dataframe. Hint: use `pandas.read_stata`.

# %%
data_url = "WRITE THE DATA URL HERE"  #TODO: Replace with the actual data URL

# Load the data
data = pd.read_stata(WRITE YOUR CODE HERE)  #TODO: Replace with the actual data loading code

# %% [markdown]
# ## Adding more regression variables
#
# Add two columns to your data:
#
# 1) a column of ones (call it intercept), and
# 2) the squre of experience (call it exper^2).
#
# Check https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.assign.html to learn how to use `assign`.

# %%
data = data.assign('<<<WRITE YOUR CODE HERE>>>')  #TODO: Replace with the actual code to create the binary variable

# %% [markdown]
# ### Design matrix
#
# Define the design matrices `X` and `y`. Make sure to select the columns you need in the order shown in the equation above; put the intercept as the first regressor.

# %%
regressors = ['<<<WRITE YOUR CODE HERE>>>']  #TODO: Write the regressor variables as a list, in order

X = data[regressors]  
y = data['<<<WRITE YOUR CODE HERE>>>']  #TODO: Replace with the actual code to select the dependent variable

# %% [markdown]
# ## Log-likelihood function
#
# Define the (**negative of the**) log-likelihoods functions required to compute the logit and probit estimators.

# %%
def logit_likelihood('<<<WRITE YOUR CODE HERE>>>') -> float:
    """ WRITE YOUR DOCSTRING HERE

    Returns:
        _type_: _description_
    """
    
    '<<<WRITE YOUR CODE HERE>>>'
    
    return -log_likelihood_value  # We minimize the negative log-likelihood



def probit_likelihood('<<<WRITE YOUR CODE HERE>>>') -> float:
    """ WRITE YOUR DOCSTRING HERE
    Returns:
        _type_: _description_
    """
    
    '<<<WRITE YOUR CODE HERE>>>'
    
    return -log_likelihood_value  # We minimize the negative log-likelihood

# %% [markdown]
# ## Estimating the model
# Compute the three estimators and store their results in a pandas dataframe. Print your result.
#
# Use the `minimize` function from scipy (hint: add `from scipy.optimize import minimize` in the Import section at the beginning) to compute the ML estimators. Check its documentation here: https://docs.scipy.org/doc/scipy/reference/generated/scipy.optimize.minimize.html
#
#
# **Hint**: Remember that the OLS estimator is $(X'X)^{-1}X'y$

# %% [markdown]
# ### OLS

# %%
'<<<WRITE YOUR CODE HERE>>>'
ols_coef = '<<<WRITE YOUR CODE HERE>>>'  #TODO: Replace with the actual code to compute the OLS coefficients

# %% [markdown]
# ### Logit

# %%
'<<<WRITE YOUR CODE HERE>>>'
logit_coef = '<<<WRITE YOUR CODE HERE>>>'  #TODO: Replace with the actual code to compute the Logit coefficients

# %% [markdown]
# ### Probit

# %%
'<<<WRITE YOUR CODE HERE>>>'
probit_coef = '<<<WRITE YOUR CODE HERE>>>'  #TODO: Replace with the actual code to compute the Probit coefficients

# %% [markdown]
# ### Gathering the results as a pandas DataFrame for better visualization

# %%
results = pd.DataFrame(index=regressors)  # this makes the regressors the index of the DataFrame

results['OLS'] = ols_coef
results['Logit'] = '<<<WRITE YOUR CODE HERE>>>'
results['Probit'] = '<<<WRITE YOUR CODE HERE>>>'

# %% [markdown]
# # Learning more
#
# The `minimize` function from `scipy` can also solve **constrained optimization** problems! This function is very helpful for machine learning algorithms.
#
# Check some additional examples here https://pythonguides.com/python-scipy-minimize/
