# %% [markdown]
# <link rel="stylesheet" href="style.css">
#
# <p class="title_header">slv03:  A linear fixed-point problem</p>
#
# What could go wrong with function iteration? Let's find out!
#
# <p class="student">Student Name should go here!!</p>

# %% [markdown]
# # The problem:
#
# Consider the problem of finding the fixed-point of the function
# $$ g(x) = 1 − b + bx $$

# %% [markdown]
# ## Convergence?
#
# According to the Contraction Mapping Theorem, for which values of $b$ will function iteration converge to fixed-point of $g$?

# %% [markdown]
# WRITE YOUR ANSWER HERE USING MARKDOWN

# %% [markdown]
# ## Function iteration
#
# Write a Python function for `g`. Make sure that the parameter `b` is used *inside* the function, yet its value is fixed *outside* the function.

# %%
b = -2  #first value of b

def g(x):
    return '<<<WRITE YOUR CODE HERE>>>'

# %% [markdown]
# Write a Python script that will compute the fixed-point of $g$ using function iteration and report the results when you run it for $b = −2, 0, 1, 2$ starting from an initial iterate $x_0 = 0.5$.

# %% [markdown]
# ### Case 1: b = -2

# %%
b = -2

'<<<WRITE YOUR CODE HERE>>>'

# %% [markdown]
# ### Case 2: b = 0

# %%
b = 0

'<<<WRITE YOUR CODE HERE>>>'

# %% [markdown]
# ### Case 3: b = 1

# %%
b = '<<<WRITE YOUR CODE HERE>>>'

'<<<WRITE YOUR CODE HERE>>>'

# %% [markdown]
# ### Case 4: b = 2

# %%
'<<<WRITE YOUR CODE HERE>>>'
