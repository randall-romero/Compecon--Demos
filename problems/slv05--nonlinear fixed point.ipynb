# %% [markdown]
# <link rel="stylesheet" href="style.css">
#
# <p class="title_header">slv05:  A nonlinear fixed-point problem</p>
#
#
#
# <p class="student">Student Name should go here!!</p>

# %% [markdown]
# # The problem:
#
# Implement the function iteration algorithm to find the root of
#
# \begin{equation*}
# f(x) = \sin\left(\sqrt{x}\right) - x
# \end{equation*}
#
# Use $x_0=0.5$ as your initial value and make as many iterations as necessary to get that two consecutive iteration values be within $10^{-7}$ from each other.

# %% [markdown]
# ## Function iteration, without CompEcon
#
# Write your own `for` loop to implement function iteration.

# %%
x = # initial value here

# [WRITE YOUR CODE HERE]

# %% [markdown]
# ## Function iteration, with CompEcon
#
# Use `NLP` to find the fixed point

# %%
import  # <<<WRITE YOUR CODE HERE>>>'

x = # [WRITE YOUR CODE HERE]

# %% [markdown]
# Did you get the same values?
