# %% [markdown]
# <link rel="stylesheet" href="style.css">
#
# <p class="title_header">slv04:  The Black-Scholes formula</p>
#
# Scholes and Merton received the Nobel Memorial Prize in Economic Sciences in 1997 for their work in finding "a new method to determine the value of derivatives".
#
# The formula is quite non-linear. Let's see how we can compute its implied volatility!
#
# <p class="student">Student Name should go here!!</p>

# %% [markdown]
# # The problem:
#
# The Black-Scholes option pricing formula expresses the price $C$ of a European call option on a stock in terms of the price $S$ of the underlying stock, the strike price $K$, the time in years $\tau$ until the expiration of the option, the continuously compounded risk-free interest rate $r$, and the
# annualized volatility $\sigma$ of the price of the underlying stock:
#
# $$ C = S\Phi(d) − Ke^{−r\tau}\Phi(d − \sigma\sqrt{\tau})$$
#
# where
#
# $$ d = \frac{ln(S/K) + (r + 0.5\sigma^2)\tau}{\sigma\sqrt{\tau}} $$
#
# and $\Psi$ is the standard normal cumulative distribution function. All of the inputs to the Black-Scholes formula are readily observable, except the volatility $\sigma$ of underlying stock price.

# %% [markdown]
# ## Solving for the implied volatility
#
# Compute the **“implied volatility”** of the underlying stock price if a stock call option expiring in one year with strike price $K = 1.1$ is currently trading a price $C =0.0728$, the underlying stock is trading at a price $S = 1$, and the risk-free interest rate is $r = 0.08$.

# %% [markdown]
# ## Importing
# Hint: to compute $\Phi$, use `from scipy.stats import norm`, then `norm.cdf()`.

# %%
import '<<<WRITE YOUR CODE HERE>>>'

Φ = norm.cdf # cumulative distribution function for the standard normal distribution

# %% [markdown]
# ##  cdf vs. cdf()
#
# Explain how these two lines of code are different:
# ```
# phi = norm.cdf()
# phi = norm.cdf
# ```

# %% [markdown]
# WRITE YOUR ANSWER HERE USING MARKDOWN

# %% [markdown]
# ## Problem parameters

# %%
τ = '<<<WRITE YOUR CODE HERE>>>'
K = '<<<WRITE YOUR CODE HERE>>>'
C = '<<<WRITE YOUR CODE HERE>>>'
S = '<<<WRITE YOUR CODE HERE>>>'
r = '<<<WRITE YOUR CODE HERE>>>'

# %% [markdown]
# ## Define the relevant functions
# Our task is easier to solve if we make a helper function for `d` in the Black-Scholes formula. We make it depend only on `σ` because all other parameters are known!
#
# $$ d = \frac{ln(S/K) + (r + 0.5\sigma^2)\tau}{\sigma\sqrt{\tau}} $$

# %%
def d(σ):
    return '<<<WRITE YOUR CODE HERE>>>'

# %% [markdown]
# ## A root-finding problem
#
# Now define `f(σ)` as a function that is zero when σ satisfies
#
# $$ C = S\Phi(d) − Ke^{−r\tau}\Phi(d − \sigma\sqrt{\tau})$$

# %%
def f(σ):
    '<<<WRITE YOUR CODE HERE>>>'

# %% [markdown]
# ## Find σ
#
# You are ready to find the implied volatility.

# %%
'<<<WRITE YOUR CODE HERE>>>'

# %% [markdown]
# # Learning more
#
# Scholes and Merton received the Nobel Memorial Prize in Economic Sciences in 1997 for their work in finding "a new method to determine the value of derivatives". Learn more about their formula here: https://www.investopedia.com/terms/b/blackscholes.asp
