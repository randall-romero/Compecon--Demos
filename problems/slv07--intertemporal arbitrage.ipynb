# %% [markdown]
# <link rel="stylesheet" href="style.css">
#
# <p class="title_header">slv07:  An intertemporal arbitrage model</p>
#
#
#
# <p class="student">Student Name should go here!!</p>

# %% [markdown]
# # The problem:
#
# Consider the potato market. Assume that potatos can be consumed in one of two periods only (that is, they can be consumed when harvested in $t=1$, or in period $t=2$ after being stored). Thus, this restriction must be satisfied:
#
# \begin{equation*}
# s = c_1 + c_2
# \end{equation*}
#
# where $c_t$ is consumption in period $t$.
#
# Competion among potato storers eliminates arbitrage opportunities, so that
#
# \begin{equation*}
# p_1 + \kappa = \delta p_2
# \end{equation*}
#
# where $p_t$ is the equilibrium price in period $t$, $\kappa = 0.2$ the unit cost of storing potators for one period, and $\delta=0.95$ is a discount factor. Demand in each period is
#
# \begin{equation*}
# p_t = c_t^{-5}
# \end{equation*}
#
# Compute the equilibrium prices $p_1,p_2$ for when the harvest size is $s=1$, $s=2$ and $s=3$.

# %% [markdown]
# ## Getting ready: import
#
# Import what you need from `CompEcon` and other packages.

# %%
# [WRITE YOUR CODE HERE]

# %% [markdown]
# ## Write the required functions
#
# Code a function `potatos` that takes as argument a vector of consumptions (one for each period) and returns a vector of size 2. The vector must be zero if and only if the resouce constraint and the intertemporal constraint are satisfied.

# %%
def potatos(c):
    # [WRITE YOUR CODE HERE]
    pass

# %% [markdown]
# ## Solve the system using Broyden's method.
#
# ### When $s=1$

# %%
# [WRITE YOUR CODE HERE]

# %% [markdown]
# ### When $s=2$

# %%
# [WRITE YOUR CODE HERE]

# %% [markdown]
# ### When $s=3$

# %%
# [WRITE YOUR CODE HERE]

# %% [markdown]
# ## Compare the results
#
# Make a pandas dataframe to compare your results.
#
# The table must have:
#
# - two rows, representing the two periods.
# - 6 columns, representing price and consumption for each harvest size.
#
# Use a **multiindex** to properly identify the columns. Check https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.MultiIndex.html for details.

# %%
# [WRITE YOUR CODE HERE]

# %% [markdown]
# ## Relative price
#
# Compute the relative price of period-2 potatos in terms of period-1 potatos. Is it constant? Plot the result (relative price in y-axis, harvest size in x-axis). What do you observe?

# %%
# [WRITE YOUR CODE HERE]

# %% [markdown]
# ## Substitution effects
#
# Compute the share of the harvest that is consumed in the first period, for each harvest level, and plot the result (share in y-axis, harvest size in x-axis). Is this result consistent with what you observe in the relative prices?

# %%
# [WRITE YOUR CODE HERE]
