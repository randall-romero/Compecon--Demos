# %% [markdown]
# # Maintenance

# %% [markdown]
# This notebook is just for housekeeping.

# %% [markdown]
# ## Delete all output from notebooks

# %%
# !jupyter nbconvert --ClearOutputPreprocessor.enabled=True --inplace app\*.ipynb
# !jupyter nbconvert --ClearOutputPreprocessor.enabled=True --inplace ddp\*.ipynb
# !jupyter nbconvert --ClearOutputPreprocessor.enabled=True --inplace dif\*.ipynb
# !jupyter nbconvert --ClearOutputPreprocessor.enabled=True --inplace dp\*.ipynb
# !jupyter nbconvert --ClearOutputPreprocessor.enabled=True --inplace intro\*.ipynb
# !jupyter nbconvert --ClearOutputPreprocessor.enabled=True --inplace lin\*.ipynb
# !jupyter nbconvert --ClearOutputPreprocessor.enabled=True --inplace math\*.ipynb
# !jupyter nbconvert --ClearOutputPreprocessor.enabled=True --inplace opt\*.ipynb
# !jupyter nbconvert --ClearOutputPreprocessor.enabled=True --inplace py\*.ipynb
# !jupyter nbconvert --ClearOutputPreprocessor.enabled=True --inplace qua\*.ipynb
# !jupyter nbconvert --ClearOutputPreprocessor.enabled=True --inplace slv\*.ipynb
# Out:
# [NbConvertApp] Converting notebook app\00 Approximation using CompEcon toolbox.ipynb to notebook
# [NbConvertApp] Writing 8327 bytes to app\00 Approximation using CompEcon toolbox.ipynb
# [NbConvertApp] Converting notebook app\01 Approximating function on R.ipynb to notebook
# [NbConvertApp] Writing 10254 bytes to app\01 Approximating function on R.ipynb
# [NbConvertApp] Converting notebook app\02 Approximating functions on R2.ipynb to notebook
# [NbConvertApp] Writing 10639 bytes to app\02 Approximating functions on R2.ipynb
# [NbConvertApp] Converting notebook app\03 Basis functions and standard nodes for major approximation schemes.ipynb to notebook
# [NbConvertApp] Writing 4567 bytes to app\03 Basis functions and standard nodes for major approximation schemes.ipynb
# [NbConvertApp] Converting notebook app\04 Approximating Runge's function.ipynb to notebook
# [NbConvertApp] Writing 6196 bytes to app\04 Approximating Runge's function.ipynb
# ...

# %% [markdown]
# ## Delete all .ipycheckpoints

# %%
# !rmdir /Q /S .ipynb_checkpoints
# !rmdir /Q /S app\.ipynb_checkpoints
# !rmdir /Q /S ddp\.ipynb_checkpoints
# !rmdir /Q /S dif\.ipynb_checkpoints
# !rmdir /Q /S dp\.ipynb_checkpoints
# !rmdir /Q /S intro\.ipynb_checkpoints
# !rmdir /Q /S lin\.ipynb_checkpoints
# !rmdir /Q /S math\.ipynb_checkpoints
# !rmdir /Q /S opt\.ipynb_checkpoints
# !rmdir /Q /S py\.ipynb_checkpoints
# !rmdir /Q /S qua\.ipynb_checkpoints
# !rmdir /Q /S slv\.ipynb_checkpoints
# Out:
# The system cannot find the file specified.
# The system cannot find the file specified.
# The system cannot find the file specified.
# The system cannot find the file specified.
# The system cannot find the file specified.
# The system cannot find the file specified.
# The system cannot find the file specified.
# The system cannot find the file specified.
# The system cannot find the file specified.
# The system cannot find the file specified.
# The system cannot find the file specified.

# %%
import os
print(os.getcwd())

# !rmdir /Q /S .ipynb_checkpoints
for folder in ['app','ddp','dif','doc','dp','intro','math','ode','opt','qua','slv','soc']:
    target = folder + "\.ipynb_checkpoints"
    print(target)
    # !rmdir /Q /S $target
# Out:
# C:\Users\randa\OneDrive\Documents\Python\CompEcon\notebooks
# app\.ipynb_checkpoints
# The system cannot find the file specified.
# ddp\.ipynb_checkpoints
# The system cannot find the path specified.
# dif\.ipynb_checkpoints
# The system cannot find the path specified.
# doc\.ipynb_checkpoints
# The system cannot find the path specified.
# dp\.ipynb_checkpoints
# The system cannot find the path specified.
# intro\.ipynb_checkpoints
# The system cannot find the path specified.
# math\.ipynb_checkpoints
# The system cannot find the path specified.
# ode\.ipynb_checkpoints
# The system cannot find the path specified.
# opt\.ipynb_checkpoints
# The system cannot find the path specified.
# qua\.ipynb_checkpoints
# The system cannot find the path specified.
# slv\.ipynb_checkpoints
# The system cannot find the path specified.
# soc\.ipynb_checkpoints
# The system cannot find the file specified.
# The system cannot find the file specified.
