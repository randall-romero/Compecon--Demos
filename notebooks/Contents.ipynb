# %% [markdown]
# # CompEcon Demos

# %% [markdown]
# The following lists show all the demo files that are available in the MATLAB version of CompEcon, by Mario Miranda and Paul Fackler.  Some of these demos have been ported to Python; for them a hyperlink to the correspoding Jupyter notebook is provided.
#
# _Randall Romero-Aguilar_
#
# April 2016
#
# Last updated: 21 March 2026

# %% [markdown]
# ## 00 Mathematics Review
#  * demmath01 --  [Taylor Approximations](<00-Mathematics/01 Taylor Approximations.ipynb>)
#  * demmath02  -- [Computing Function Inner Products, Norms & Metrics](<00-Mathematics/02 Computing Function Inner Products, Norms, and Metrics.ipynb>)
#  * demmath03  -- [Continuous Distribution CDFs and PDFs](<00-Mathematics/03 Major Distribution CDFs and PDFs.ipynb>)
#  * demmath04  --  Standard Copulas
#  * demmath05  --  Illustrates Implicit Function Theorem
#  * demmath06  --  Simulate Simple Markov Chain
#  * demmath07  --  Operations with Markov Chains

# %% [markdown]
# ## 01 Introduction
#  * demintro01 --  [Inverse Demand Problem](<01-Introduction/01 Inverse Demand Problem.ipynb>)
#  * demintro02 --  [Rational Expectations Agricultural Market Model](<"01-Introduction/02 Rational Expectations Agricultural Market Model.ipynb">)

# %% [markdown]
# ## 02 Linear Equations
#  * demlin01   --  [Solving Linear Equations by Different Methods](<02-Linear Equations/01 Solving linear equations by different methods.ipynb>)
#  * demlin02   --  [Ill-Conditioning of Vandermonde Matrix](<02-Linear Equations/02 Ill-conditioning of Vandermonde matrix.ipynb>)
#  * demlin03   --  [Sparse Linear Equations](<02-Linear Equations/03 Sparse linear equations.ipynb>)

# %% [markdown]
# ## 03 Nonlinear Equations
#  * demslv01 --  [Compute Root of f(x)=exp(-x)-1](<03-Nonlinear Equations/01 Compute root of f%28x%29=exp%28-x%29-1.ipynb>)
#  * demslv02 --  [Compute Root of Rosencrantz Function](<03-Nonlinear Equations/02 Compute root of Rosencrantz function.ipynb>)
#  * demslv03 --  [Compute Fixedpoint of f(x) = x^0.5](<03-Nonlinear Equations/03 Compute fixedpoint of f%28x%29 = sqrt%28x%29.ipynb>)
#  * demslv04 --  [Compute Fixedpoint of f(x1,x2)= x1^2+x2^3;x1*x2-0.5](<03-Nonlinear Equations/04 Compute fixedpoint of f%28x1,x2%29= [x1 2+x2 3; x1 x2 - 0.5].ipynb>)
#  * demslv05 --  [Illustrates Newton and Broyden Paths](<03-Nonlinear Equations/05 Cournot equilibrium model.ipynb>)
#  * demslv06 --  [Illustrates Function Iteration, Newton, and Secand Methods](<03-Nonlinear Equations/06 Illustrates function iteration, Newton, and secant methods.ipynb>)
#  * demslv07 --  [Linear Complementarity Problem Methods](<03-Nonlinear Equations/07 Linear complementarity problem methods.ipynb>)
#  * demslv08 --  [Nonlinear Complementarity Problem Methods](<03-Nonlinear Equations/08 Nonlinear complementarity problem methods.ipynb>)
#  * demslv09 --  [Hard Nonlinear Complementarity Problem with Billup's Function](<03-Nonlinear Equations/09 Hard nonlinear complementarity problem with Billup's function.ipynb>)
#  * demslv10 --  [Illustrates Linear Complementarity Problem](<03-Nonlinear Equations/10 Illustrates linear complementarity problem.ipynb>)
#  * demslv11 --  Nonlinear Complementarity Problem Methods
#  * demslv12 --  [Convergence Rates for Nonlinear Equation Methods](<03-Nonlinear Equations/12 Convergence rates for nonlinear equation methods.ipynb>)
#  * demslv13 --  [Simple Nonlinear Complementarity Problem](<03-Nonlinear Equations/13 Simple nonlinear complementarity problem.ipynb>)
#  * demslv14 --  [Spatial Equilibrium Model](<03-Nonlinear Equations/14 Spacial Equilibrium Model.ipynb>)

# %% [markdown]
# ## 04 Finite-Dimensional Optimization
#  * demopt01   --  Maximization via Golden Search
#  * demopt02   --  Changes in Nelder-Mead Simplex
#  * demopt03   --  Nelder-Mead Simplex Method
#  * demopt04   --  [Maximization of Banana Function, Various Methods](<04-Finite-Dimensional Optimization/04 Maximization of banana function by various methods.ipynb>)
#  * demopt05   --  [Optimization with qnewton](<04-Finite-Dimensional Optimization/05 Optimization with qnewton.ipynb>)
#  * demopt06   --  [KKT Conditions for Constrained Optimization Problems](<04-Finite-Dimensional Optimization/06 KKT conditions for constrained optimization problems.ipynb>)
#  * demopt07   --  Bound Constrained Optimization via Sequential LCP
#  * demopt08   --  [Constrained Optimization with nlpsolve](<04-Finite-Dimensional Optimization/08 Constrained optimization using scipy.ipynb>)
#  * demopt50   --  [Poisson MLE](<04-Finite-Dimensional Optimization/50 Poisson MLE.ipynb>)

# %% [markdown]
# ## 05 Integration
#  * demqua01   --  [Equidistributed Sequences on Unit Square in R^2](<05-Integration/01 Equidistributed sequences on unit square in R2.ipynb>)
#  * demqua01bis -- [Computing Integral with quasi-Monte Carlo methods](<05-Integration/01bis Computing integral with quasi-Monte Carlo methods.ipynb>)
#  * demqua02   --  Compute Expectation of Function of Random Normal Vector
#  * demqua03   --  [Area under 1-D and 2-D Curves, Various Methods](<05-Integration/03 Area under 1-D and 2-D curves, various methods.ipynb>)
#  * demqua04   --  [Area under Normal PDF Using Simpson's Rule](<05-Integration/04 Area under normal pdf using Simpson's rule.ipynb>)
#  * demqua05   --  Willingness to Pay, Expected Utility Model
#  * demqua06   --  [Area under a Curve](<05-Integration/06 Area under a curve.ipynb>)
#  * demqua07   --  [Integration Using Trapezoidal Rule](<05-Integration/07 Illustrates integration using Trapezoidal rule.ipynb>)
#  * demqua08   --  [Integration Using Simpson's Rule](<05-Integration/08 Illustrates integration using Simpson's rule.ipynb>)
#  * demqua09   --  Chebychev and Legendre Quadrature Nodes and Weights
#  * demqua10   --  [Monte Carlo Simulation of Time Series](<05-Integration/10 Monte Carlo Simulation of Time Series.ipynb>)

# %% [markdown]
# ## 06 Differentiation
#  * demdif01   --  Finite Difference Hessian Evaluation
#  * demdif02   --  Error in Finite Difference Differentiation
#  * demdif03   --  Demonstrates fdjac and checkjac
#  * demdif04   --  Demonstrates fdhess
#  * demdif02 -- [Demonstrates accuracy of one- and two-sided-difference derivatives](<06-Differentiation/02 Demonstrates accuracy of one- and two-sided finite-difference derivatives.ipynb>)

# %% [markdown]
# ## 07 Function Approximation
#  * demapp00 --  [Approximating using CompEcon toolbox](<07-Function Approximation/00 Approximation using CompEcon toolbox.ipynb>)
#  * demapp01 --  [Approximating Functions on R](<07-Function Approximation/01 Approximating function on R.ipynb>)
#  * demapp02 --  [Approximating Functions on R^2](<07-Function Approximation/02 Approximating functions on R2.ipynb>)
#  * demapp03 --  [Basis Functions and Standard Nodes for Major Approximation Schemes](<07-Function Approximation/03 Basis functions and standard nodes for major approximation schemes.ipynb>)
#  * demapp04 --  [Uniform-Node and Chebychev-Node Polynomial Approximation of Runge's Function](<07-Function Approximation/04 Approximating Runge's function.ipynb>)
#  * demapp05 --  [Chebychev Polynomial and Spline Approximation of Various Functions](<07-Function Approximation/05 Chebychev polynomial and spline approximantion of various functions.ipynb>)
#  * demapp06 -- [Chebyshev and Cubic Spline Derivative Approximation Errors](<07-Function Approximation/06 Chebychev and cubic spline derivative approximation errors.ipynb>)
#  * demapp07 --  [Solve Cournot Oligopoly Model via Collocation](<07-Function Approximation/07 Solve Cournot oligopoly model via collocation.ipynb>)
#  * demapp08 --  [Compute Function Inverse via Collocation](<07-Function Approximation/08 Compute function inverse via collocation.ipynb>)
#  * demapp09 --  [Linear Spline Approximation](<07-Function Approximation/09 Linear spline approximation.ipynb>)
#  * demapp10 --  [Monopolist's Effective Supply Function](<07-Function Approximation/10 Monopolist's Effective Supply Function.ipynb>)

# %% [markdown]
# ## 08 Discrete Time Discrete State Dynamic Programming
#  * demddp01 --  [Mine Management Model](<08-Discrete State Models/01 Mine management model.ipynb>)
#  * demddp02 --  [Asset Replacement Model](<08-Discrete State Models/02 Asset replacement model.ipynb>)
#  * demddp03 --  [Asset Replacement Model With Maintenance](<08-Discrete State Models/03 Asset replacement model with maintenance.ipynb>)
#  * demddp04   --  Binomial American Put Option Model
#  * demddp05   --  Water Management Model
#  * demddp06   --  Bioeconomic Model
#  * demddp07   --  Renewable Resource Model
#  * demddp08   --  Job Search Model
#  * demddp09   --  Deterministic Cow Replacement Model
#  * demddp10   --  Stochastic Cow Replacement Model
#  * demddp11   --  Stochastic Optimal Growth Model

# %% [markdown]
# ## 09 Discrete Time Continuous State Dynamic Programming
#  * demdp01 --  [Timber Harvesting Model](<09-Continuous State Models/01 Timber Harvesting Model - Cubic Spline Approximation.ipynb>)
#  * demdp01a --  [Timber Harvesting -- 2 nodes](<09-Continuous State Models/01a Timber Harvesting -- 2 nodes.ipynb>)
#  * demdp01b --  [Timber Harvesting -- cubic spline](<09-Continuous State Models/01b Timber Harvesting -- cubic spline.ipynb>)
#  * demdp02 --  [Asset Replacement](<09-Continuous State Models/02 Asset Replacement Model.ipynb>)
#  * demdp03 --  [Industry Entry-Exit](<09-Continuous State Models/03 Industry Entry-Exit Model.ipynb>)
#  * demdp04 --  [Job Search](<09-Continuous State Models/04 Job Search Model.ipynb>)
#  * demdp05 --  [American Put Option Pricing](<09-Continuous State Models/05 America Put Option Pricing Model.ipynb>)
#  * demdp06 --  [Ramsey Economic Growth Model](<09-Continuous State Models/06 Deterministic Optimal Economic Growth Model.ipynb>)
#  * demdp07 --  [Stochastic Economic Growth](<09-Continuous State Models/07 Stochastic Optimal Economic Growth Model.ipynb>)
#  * demdp08 --  [Public Renewable Management](<09-Continuous State Models/08 Public Renewable Resource Model.ipynb>)
#  * demdp09 --  [Private Non-Renewable Resource Management](<09-Continuous State Models/09 Private Non-Renewable Resource Model.ipynb>)
#  * demdp10 --  [Water Resource Management](<09-Continuous State Models/10 Water Resource Management Model.ipynb>)
#  * demdp11 --  [Monetary Policy](<09-Continuous State Models/11 Monetary Policy Model.ipynb>)
#  * demdp12 --  [Production Management](<09-Continuous State Models/12 Production Management Model.ipynb>)
#  * demdp13 --  Inventory Management
#  * demdp14 --  Livestock Feeding (Euler Conditions)
#  * demdp15 --  Saving with Transactions Costs
#  * demdp16 --  [Linear-Quadratic Problem](<09-Continuous State Models/16 Linear-Quadratic Model.ipynb>)
#  * demdp17 --  Miscellaneous Lecture Note Figures
#  * demdp18 --  Credit With Technology Adopttopm
#  * demdp19 --  Credit with Strategic Default (Broyden)
#  * demdp20 --  Lifecycle Consumption-Savings
#  * demdp21 --  Savings and Insurance Model
#  * demdp22 --  Savings and Insurance Model - Alternate, Under Development
#  * demdp23 --  Ferility Decision Model - Under Development

# %% [markdown]
# ## Rational Expectations Models
#  * dem rem01   --  Asset Pricing Model
#  * dem rem02   --  Commodity Storage Model
#  * dem rem03   --  Government Price Support Model

# %% [markdown]
# ## Dynamic Games
#  * dem game01  --  Production Capacity Game
#  * dem game02  --  Income Redistribution Game
#  * dem game03  --  Marketing Board Game

# %% [markdown]
# ## 10 Ordinary Differential Equations
#  * dem ode01   --  [Stability of Linear ODEs](<10-Differential Equations/01 Stability of Linear Homogeneous ODEs.ipynb>)
#  * dem ode02   --  [Generic Nonlinear ODE Example](<10-Differential Equations/02 Generic IVP Nonlinear ODE Example.ipynb>)
#  * dem ode03   --  [IVP Linear ODE Example](<10-Differential Equations/03  Initial Value Non-Homogeneous Linear ODE Example.ipynb>)
#  * dem ode04   --  [Non-IVP Linear ODE Example](<10-Differential Equations/04 Non-IVP Non-Homogeneous Linear ODE Example.ipynb>)
#  * dem ode05   --  [Commodity Storage Model](<10-Differential Equations/05 Commodity Storage Model.ipynb>)
#  * dem ode06   --  Predator-Prey Model
#  * dem ode07   --  Commercial Fisheries Model
#  * dem ode08   --  Lorentz Strange Attractor
#  * dem ode09   --  Tobin's Q
#  * dem ode10   --  Regional Migratio Model

# %% [markdown]
# ## Continuous Time Deterministic Optimal Control
#  * dem doc01   --  [Deterministic Optimal Economic Growth Model](<11-Deterministic Models/02 Deterministic Optimal Economic Growth Model.ipynb>)
#  * dem doc02   --  [Deterministic Nonrenewable Resource Model](<11-Deterministic Models/03 Deterministic Nonrenewable Resource Model.ipynb>)
#  * dem doc03   -- [Deterministic Renewable Resource Model](<11-Deterministic Models/04 Deterministic Renewable Resource Model.ipynb>)
#  * dem doc04   --  Deterministic Optimal Fish Harvest Model
#  * dem doc05   --  [Deterministic Production-Adjustment Model](<11-Deterministic Models/05 Deterministic Production Adjustment Model.ipynb>)

# %% [markdown]
# ## 12 Continuous Time Stochastic Optimal Control
#  * dem soc00   --  [Ito Processes](<12-Continuous Time Models/00 Ito Processes.ipynb>)
#  * dem soc01   --  [Stochastic Optimal Economic Growth Model](<12-Continuous Time Models/03 Stochastic Optimal Economic Growth Model.ipynb>)
#  * dem soc02   --  Stochastic Nonrenewable Resource Model
#  * dem soc03   --  Stochastic Renewable Resource Model
#  * dem soc04   --  Stochastic Optimal Fish Harvest Model
#  * dem soc05   --  Stochastic Production-Adjustment Model

# %% [markdown]
# ## Regime Switching Problems
#  * dem rs01    --  Asset Abandonment Model
#  * dem rs02    --  Fish Harvest Model
#  * dem rs03    --  Dixit Entry/Exit Model

# %% [markdown]
# ## Impulse Control Problems
#  * dem ic01    --  Asset Replacement Model
#  * dem ic02    --  Timber Harvesting Model
#  * dem ic03    --  Storage Management Model
#  * dem ic04    --  Capacity Choice Model
#  * dem ic05    --  Cash Management Model
#  * dem ic06    --  Fish Harvest Model

# %% [markdown]
# ## Financial Asset Pricing
#  * dem fin01   --  Cox-Ingersoll-Ross Bond Pricing Model
#  * dem fin02   --  Black-Scholes Option Pricing Model
#  * dem fin04   --  American Put Option Pricing
#  * dem fin05   --  Barrier Option Pricing
#  * dem fin06   --  Compound Bond Option Pricing
#  * dem fin07   --  Asian Option Pricing
#  * dem fin08   --  Affine Asset Pricing
#  * dem fin09   --  Financial Asset Calibration
